# %%
print("merhaba, IGU ISTKA") # prınt ekrana cıktı veren bır koddur.
# Out:
# merhaba, IGU ISTKA

# %%
print("Merhaba, Avcılar")
# Out:
# Merhaba, Avcılar

# %%
import sys # import phyton programlama dilinde yazılıma kütüphane eklemeye yarayan bir kod bloğudur
print (sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive #gooogle colab - drive bağlantısı
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/COLAB_DERSKLASORU')
# !pwd # bize kodun çıktısını dosya yolu olarak veren kod bloğudur.
# Out:
# /content/drive/My Drive/COLAB_DERSKLASORU

# %%
#Geçerli değişken tanımlaması
degisken_1 = 10
Degisken2 = 20
_degisken3 = 30

# %%
# Geçersiz değisken tanımlaması
1-degisken=40
degisken-4 =50
# Out:
#   File "<ipython-input-8-e1ab6d0ec1d0>", line 2
#     1-degisken=40
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
#Değişken tanımlama İşlemi
x=5
y="Merhaba Dünya"
print (x)
print (y)
# Out:
# 5
# Merhaba Dünya

# %% [markdown]
# Phyton programlama dilinide print komutu ekranda kullanaıcıya bilgi veren bir koddur.
# 06,08.2024 - Veri yapıları ve algorıtmalar dersi ilk kodlama çıktısıdır.
# İGÜ İSTKA SİBER AKADEMİ MERKEZİ-

# %%
#float - ondalıklı Sayı tanımlaması
b = 20.5
print(type (b))
# Out:
# <class 'float'>

# %%
#int'ten float'a çevrimin gerçekleştirilmesi
x= 10
y = float (x)
print(y,type(y))
# Out:
# 10.0 <class 'float'>

# %%
#String - Metinsel içerik tanımlaması
c= "phyton programlama"
print(c)
print(type(c))
# Out:
# phyton programlama
# <class 'str'>

# %%
# Boolean (True-False) - Doğru / Yanlış tanımlaması
d = True
e = False
print(d)
print(type(e))
# Out:
# True
# <class 'bool'>

# %%
# List - Liste tanımlaması
my_list= [1,2,3,4,5]
print(type (my_list))
print(my_list)
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5]

# %%
# Tuple - Demet  tanımlaması
my_tuple = (1,2,3,4,5)
print(type (my_tuple))
print(my_tuple)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5)

# %%
#Dictionary - Sözlük Nedir?
Sözlükler, anahtar-değer (key-value) çiftlerini depolayan veri yapılarıdır.
Her anahtar benzersizdir ve bir değere karşılık gelir.
Sözlükler sırasızdır ve değiştirilebilir.
Sözlük Metotları

keys(): Sözlüğün anahtarlarını döner.
values(): Sözlüğün değerlerini döner.
items(): Sözlüğün anahtar-değer çiftlerini döner.

# %%
#Dictionary - Sözlük Örneği --> Öğrencilerin notlarını tutan bir sözlük
notlar = {
    "Ali":85 ,
    "Veli":90,
    "Ayşe":78
}
notlar["Fatma"] = 92 # Yeni öğrenci ekleme

notlar["Ali"] = 88  #Bir öğrencinin notunu güncelleme

print(notlar)
# Out:
# {'Ali': 88, 'Veli': 90, 'Ayşe': 78, 'Fatma': 92}

# %%
print(notlar.keys()) #dict_keys(["isim","yas","meslek"])
print(notlar.keys()) #dict_values(['Ahmet',26,'Mühendis'])
print(notlar.items()) #dict_items([('isim', 'Ahmet'),('yas',26),('meslek','Mühendist)])
# Out:
# dict_keys(['Ali', 'Veli', 'Ayşe', 'Fatma'])
# dict_keys(['Ali', 'Veli', 'Ayşe', 'Fatma'])
# dict_items([('Ali', 88), ('Veli', 90), ('Ayşe', 78), ('Fatma', 92)])

# %%
# Set - Küme Örneği --> Bir yazılım etkinliğine katılan kişilerin oluşturduğu kümeler
kodyazanlar={"Ahmet","Mehmet","Ayşe"}
kodyazmayanlar= {"Ayşe","Fatma","Veli"}

# Kafasına göre Takılan Öğrenciler
ortak = kodyazanlar.intersection(kodyazmayanlar)
print("Kafasına göre Takılan Öğrenciler", ortak)

#Etkinlikte Kod yazmayan Öğrencilerin Tespiti
Kod_yazmayan =kodyazmayanlar.difference(kodyazanlar)
print("etkinlikte Kod çalışması yapmayan Öğrenci listesi",Kod_yazmayan)

# Yazılım Eğitiminin Öğrenci İmza Listesi
imza_listesi = kodyazanlar.union(kodyazmayanlar)
print("Etkinlik katılımcıları:", imza_listesi)
# Out:
# Kafasına göre Takılan Öğrenciler {'Ayşe'}
# etkinlikte Kod çalışması yapmayan Öğrenci listesi {'Veli', 'Fatma'}
# Etkinlik katılımcıları: {'Veli', 'Fatma', 'Ayşe', 'Ahmet', 'Mehmet'}

# %%
giris = input("Bir Sayı Girin;")
try:
   num = float(giris)
   print(f"Girilen sayı: {num}, tipi: {type(num)},",abs(num))
except ValueError:
    print("Geçersiz Veri girdiniz.")
# Out:
# Bir Sayı Girin;-12
# Girilen sayı: -12.0, tipi: <class 'float'>, 12.0
